# %% [markdown]
# <a href="https://colab.research.google.com/github/SantiagoGamez/SemanaTecTC1002S.103/blob/main/3_3_Actividad_Lectura_Datos_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Actividad
# (Haz doble clic en esta celda y completa los datos correspondientes a tu equipo)
#
# - Santiago Gamez

# %% [markdown]
# # Entregar
# Archivo PDF de la actividad y la liga de la actividad en su repostitorio.
#
# # Nota:
# Las tareas 1 a la 5 se califican como entregadas o no entregadas.
#
# Al integrante que no participe en la actividad no se le tomará en cuenta para la calificación.
#
# El límite para entregar las actividades es el viernes antes de las 23:59.

# %% [markdown]
# 1. Leer el archivo **netflix_titles.csv**

# %%
import pandas as pd
datos = 'https://raw.githubusercontent.com/luzeunice/arte-analitica/main/data/netflix_titles.csv'
df = pd.read_csv(datos, encoding = 'unicode_escape')

# %% [markdown]
# 2. Observa las primeras líneas usando la función head

# %%
df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...         Brazil
# 1  DemiÃ¡n Bichir, HÃ©ctor Bonilla, Oscar Serrano...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# 4    January 1, 2020          2008  PG-13    123 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %% [markdown]
# 3. Genera una función que despliegue el primer reglon del archivo.

# %%
## Esta función debe de regresar una lista con los valores del primer reglon
def top_uno():
  renglon_1 = [df.head(1)]
  return renglon_1
top_uno()
# Out:
# [  show_id     type title director  \
#  0      s1  TV Show    3%      NaN
#
#                                                  cast country       date_added  \
#  0  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...  Brazil  August 14, 2020
#
#     release_year rating   duration  \
#  0          2020  TV-MA  4 Seasons
#
#                                             listed_in  \
#  0  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                           description
#  0  In a future where the elite inhabit an island ...  ]

# %% [markdown]
# 4. Genera una función que regrese el número de registros del archivo

# %%
## Esta función tiene que entregar el número de registros del archivo
def row_number():
  return len(df)

row_number()
# Out:
# 7787

# %% [markdown]
# 5. Generar una función que entregue las películas con release_year del 2020

# %%
## Esta función tiene que entregar las películas creadas en el año 2020

year_consulta=1
def released_year(year):
  year = df[df['release_year']==2020]
  return year

released_year(year_consulta)
# Out:
#      show_id     type                                  title  \
# 0         s1  TV Show                                     3%
# 24       s25  TV Show  âSAINT SEIYA: Knights of the Zodiac
# 26       s27  TV Show                               (Un)Well
# 27       s28    Movie                                 #Alive
# 29       s30  TV Show                               #blackAF
# ...      ...      ...                                    ...
# 7725   s7726  TV Show                        You Cannot Hide
# 7734   s7735    Movie                        You've Got This
# 7738   s7739  TV Show                        Young Wallander
# 7741   s7742    Movie              Your Name Engraved Herein
# 7744   s7745    Movie            Yours Sincerely, Kanan Gill
#
#                director                                               cast  \
# 0                   NaN  JoÃ£o Miguel, Bianca Comparato, Michel Gomes, ...
# 24                  NaN  Bryson Baugus, Emily Neves, Blake Shepard, Pat...
# 26                  NaN                                                NaN
# 27               Cho Il                           Yoo Ah-in, Park Shin-hye
# 29                  NaN  Kenya Barris, Rashida Jones, Iman Benson, Genn...
# ...                 ...                                                ...
# 7725                NaN  Blanca Soto, Eduardo Noriega, IvÃ¡n SÃ¡nchez, ...
# 7734  Salvador Espinosa  Mauricio Ochmann, Esmeralda Pimentel, Matteo G...
# 7738                NaN  Adam PÃ¥lsson, Richard Dillane, Leanne Best, E...
# 7741      Liu Kuang-hui  Edward Chen, Tseng Ching-hua, Leon Dai, Jason ...
# 7744       Neville Shah                                         Kanan Gill
#
#              country         date_added  release_year rating   duration  \
# 0             Brazil    August 14, 2020          2020  TV-MA  4 Seasons
# 24             Japan   January 23, 2020          2020  TV-14  2 Seasons
# 26     United States    August 12, 2020          2020  TV-MA   1 Season
# 27       South Korea  September 8, 2020          2020  TV-MA     99 min
# 29     United States     April 17, 2020          2020  TV-MA   1 Season
# ...              ...                ...           ...    ...        ...
# 7725          Mexico    October 1, 2020          2020  TV-MA   1 Season
# 7734          Mexico    October 2, 2020          2020  TV-MA    112 min
# 7738  United Kingdom  September 3, 2020          2020  TV-MA   1 Season
# 7741          Taiwan  December 23, 2020          2020  TV-MA    115 min
# 7744           India     April 24, 2020          2020  TV-MA     72 min
#
#                                               listed_in  \
# 0     International TV Shows, TV Dramas, TV Sci-Fi &...
# 24                 Anime Series, International TV Shows
# 26                                           Reality TV
# 27       Horror Movies, International Movies, Thrillers
# 29                                          TV Comedies
# ...                                                 ...
# 7725  Crime TV Shows, International TV Shows, Spanis...
# 7734    Comedies, International Movies, Romantic Movies
# 7738  Crime TV Shows, International TV Shows, TV Dramas
# 7741         Dramas, International Movies, LGBTQ Movies
# 7744                                    Stand-Up Comedy
#
#                                             description
# 0     In a future where the elite inhabit an island ...
# 24    Seiya and the Knights of the Zodiac rise again...
# 26    This docuseries takes a deep dive into the luc...
# 27    As a grisly virus rampages a city, a lone man ...
# 29    Kenya Barris and his family navigate relations...
# ...                                                 ...
# 7725  A nurse and her daughter flee her husbandâs ...
# 7734  An ad creative and aÂ successful execÂ have a ...
# 7738  An incendiary hate crime stirs civil unrest, f...
# 7741  In 1987, as martial law ends in Taiwan, Jia-ha...
# 7744  Revisiting life goals set in a letter written ...
#
# [868 rows x 12 columns]

# %% [markdown]
# 6. Películas con la columna de contry='Mexico'

# %%
## Esta función tiene que entregar las películas creadas en Mexico
pais_consulta='x'

def country_year(pais_consulta):
  pais_consulta = df[df['country'] == 'Mexico']
  return pais_consulta

country_year(pais_consulta)
# Out:
#      show_id     type                                            title  \
# 1         s2    Movie                                             7:19
#
#                                             description
# 1     After a devastating earthquake hits Mexico Cit...
# 12    Archival video and new interviews examine Mexi...
# 292   Three lifelong friends travel to Acapulco oste...
# 370   Mexican comic Alan SaldaÃ±a has fun with every...
# 378   Comic Alex FernÃ¡ndez performs his familiar au...
# ...                                                 ...
# 7698  On the run from the police, an Arizona man cro...
# 7725  A nurse and her daughter flee her husbandâs ...
# 7734  An ad creative and aÂ successful execÂ have a ...
# 7773  This introspective rockumentary follows the ca...
# 7779  An assortment of talent takes the stage for a ...
#
# [100 rows x 12 columns]

# %% [markdown]
# **Ejercicio de apply**
#
# Genrar una función que obtenga el cuadrado de un número y llamala cuadrado.

# %%
def cuadrado(x):
  x = x*x
  return x
cuadrado(2)
# Out:
# 4

# %% [markdown]
# Usando la instruccion **apply** generar el cuadrado de todos los valores del siguiente dataframe.
#
# Ultiliza la función que definiste en el paso anterior.

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3, 5, 6], 'B': [10, 20, 30, 40, 50]})
df = df.apply(cuadrado)
df
# Out:
#     A     B
# 0   1   100
# 1   4   400
# 2   9   900
# 3  25  1600
# 4  36  2500

# %% [markdown]
# **Ejercicio de map**
#
# Calcular la longitud del contenido de todas las celdas del datafame usando **lambda** y la operación **map**

# %%
import pandas as pd

df = pd.DataFrame({'Nombre': ['Luz', 'Eunice','Ignacio','José'], 'Apellido': ['Angeles', 'Ochoa','Treviño','Zapata']})
dff = list(map(lambda x : len(x), df))
dff
# Out:
# [6, 8]

# %% [markdown]
# # Guardar el resultado como pdf

# %% [markdown]
# * Escribe aquí abajo la liga de tu repositorio.
#
# * (Haz doble clic en esta celda y copia la URL dentro del paréntesis)
#
# [Liga al repositorio de Santiago Gamez](https://github.com/SantiagoGamez/SemanaTecTC1002S.103)

# %% [markdown]
# * Exporta el notebook a formato HTML.

# %%
! jupyter nbconvert --to HTML '/content/drive/MyDrive/SemanaTec/arte-analitica/3.3 - Actividad - Lectura Datos - Pandas.ipynb'
# Out:
# [NbConvertApp] WARNING | pattern '/content/drive/MyDrive/SemanaTec/arte-analitica/3.3 - Actividad - Lectura Datos - Pandas.ipynb' matched no files
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# =======
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
#     Equivalent to: [--JupyterApp.generate_config=True]
# -y
#     Answer yes to any questions instead of prompting.
#     Equivalent to: [--JupyterApp.answer_yes=True]
# --execute
#     Execute the notebook prior to export.
#     Equivalent to: [--ExecutePreprocessor.enabled=True]
# --allow-errors
#     Continue notebook execution even if one of the cells throws an error and include the error message in the cell output (the default behaviour is to abort conversion). This flag is only relevant if '--execute' was specified, too.
#     Equivalent to: [--ExecutePreprocessor.allow_errors=True]
# --stdin
#     read a single notebook file from stdin. Write the resulting notebook with default basename 'notebook.*'
#     Equivalent to: [--NbConvertApp.from_stdin=True]
# --stdout
#     Write notebook output to stdout instead of files.
#     Equivalent to: [--NbConvertApp.writer_class=StdoutWriter]
# --inplace
#     Run nbconvert in place, overwriting the existing notebook (only
#             relevant when converting to notebook format)
#     Equivalent to: [--NbConvertApp.use_output_suffix=False --NbConvertApp.export_format=notebook --FilesWriter.build_directory=]
# --clear-output
#     Clear output of current file and save in place,
#             overwriting the existing notebook.
#     Equivalent to: [--NbConvertApp.use_output_suffix=False --NbConvertApp.export_format=notebook --FilesWriter.build_directory= --ClearOutputPreprocessor.enabled=True]
# --no-prompt
#     Exclude input and output prompts from converted document.
#     Equivalent to: [--TemplateExporter.exclude_input_prompt=True --TemplateExporter.exclude_output_prompt=True]
# --no-input
#     Exclude input cells and output prompts from converted document.
#             This mode is ideal for generating code-free reports.
#     Equivalent to: [--TemplateExporter.exclude_output_prompt=True --TemplateExporter.exclude_input=True]
# --log-level=<Enum>
#     Set the log level by value or name.
#     Choices: any of [0, 10, 20, 30, 40, 50, 'DEBUG', 'INFO', 'WARN', 'ERROR', 'CRITICAL']
#     Default: 30
#     Equivalent to: [--Application.log_level]
# --config=<Unicode>
#     Full path of a config file.
#     Default: ''
#     Equivalent to: [--JupyterApp.config_file]
# --to=<Unicode>
#     The export format to be used, either one of the built-in formats
#             ['asciidoc', 'custom', 'html', 'latex', 'markdown', 'notebook', 'pdf', 'python', 'rst', 'script', 'slides']
#             or a dotted object name that represents the import path for an
#             `Exporter` class
#     Default: 'html'
#     Equivalent to: [--NbConvertApp.export_format]
# --template=<Unicode>
#     Name of the template file to use
#     Default: ''
#     Equivalent to: [--TemplateExporter.template_file]
# --writer=<DottedObjectName>
#     Writer class used to write the
#                                         results of the conversion
#     Default: 'FilesWriter'
#     Equivalent to: [--NbConvertApp.writer_class]
# --post=<DottedOrNone>
#     PostProcessor class used to write the
#                                         results of the conversion
#     Default: ''
#     Equivalent to: [--NbConvertApp.postprocessor_class]
# --output=<Unicode>
#     overwrite base name use for output files.
#                 can only be used when converting one notebook at a time.
#     Default: ''
#     Equivalent to: [--NbConvertApp.output_base]
# --output-dir=<Unicode>
#     Directory to write output(s) to. Defaults
#                                   to output to the directory of each notebook. To recover
#                                   previous default behaviour (outputting to the current
#                                   working directory) use . as the flag value.
#     Default: ''
#     Equivalent to: [--FilesWriter.build_directory]
# --reveal-prefix=<Unicode>
#     The URL prefix for reveal.js (version 3.x).
#             This defaults to the reveal CDN, but can be any url pointing to a copy
#             of reveal.js.
#             For speaker notes to work, this must be a relative path to a local
#             copy of reveal.js: e.g., "reveal.js".
#             If a relative path is given, it must be a subdirectory of the
#             current directory (from which the server is run).
#             See the usage documentation
#             (https://nbconvert.readthedocs.io/en/latest/usage.html#reveal-js-html-slideshow)
#             for more details.
#     Default: ''
#     Equivalent to: [--SlidesExporter.reveal_url_prefix]
# --nbformat=<Enum>
#     The nbformat version to write.
#             Use this to downgrade notebooks.
#     Choices: any of [1, 2, 3, 4]
#     Default: 4
#     Equivalent to: [--NotebookExporter.nbformat_version]
#
# Examples
# --------
#
#     The simplest way to use nbconvert is
#
#             > jupyter nbconvert mynotebook.ipynb
#
#             which will convert mynotebook.ipynb to the default format (probably HTML).
#
#             You can specify the export format with `--to`.
#             Options include ['asciidoc', 'custom', 'html', 'latex', 'markdown', 'notebook', 'pdf', 'python', 'rst', 'script', 'slides'].
#
#             > jupyter nbconvert --to latex mynotebook.ipynb
#
#             Both HTML and LaTeX support multiple output templates. LaTeX includes
#             'base', 'article' and 'report'.  HTML includes 'basic' and 'full'. You
#             can specify the flavor of the format used.
#
#             > jupyter nbconvert --to html --template basic mynotebook.ipynb
#
#             You can also pipe the output to stdout, rather than a file
#
#             > jupyter nbconvert mynotebook.ipynb --stdout
#
#             PDF is generated via latex
#
#             > jupyter nbconvert mynotebook.ipynb --to pdf
#
#             You can get (and serve) a Reveal.js-powered slideshow
#
#             > jupyter nbconvert myslides.ipynb --to slides --post serve
#
#             Multiple notebooks can be given at the command line in a couple of
#             different ways:
#
#             > jupyter nbconvert notebook*.ipynb
#             > jupyter nbconvert notebook1.ipynb notebook2.ipynb
#
#             or you can specify the notebooks list in a config file, containing::
#
#                 c.NbConvertApp.notebooks = ["my_notebook.ipynb"]
#
#             > jupyter nbconvert --config mycfg.py
#
# To see all available configurables, use `--help-all`.

# %% [markdown]
# * Haz doble clic en el archivo nuevo que se creó dentro de la carpeta `arte-analitica` y en la parte superior derecha dale clic en **imprimir**
#
# * Imprime el archivo como *PDF* y súbelo a Canvas.
